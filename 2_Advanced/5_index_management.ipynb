# %%
import pandas as pd 
import matplotlib.pyplot as plt
from datasets import load_dataset

# loading the data
dataset= load_dataset('lukebarousse/data_jobs')
df= dataset['train'].to_pandas()

# converting to the right time value

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['job_country'].value_counts()
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Mauritania             3
# Lesotho                3
# Bhutan                 3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
german_jobs = df[df['job_country'] == 'Germany']

# %%
german_jobs.head(5)
# Out:
#               index        job_title_short  \
# index_number
# 2                 0          Data Engineer
# 34                1           Data Analyst
# 64                2    Senior Data Analyst
# 78                3  Senior Data Scientist
# 104               4      Software Engineer
#
#                                                       job_title  \
# index_number
# 2             Data Engineer/Scientist/Analyst, Mid or Senior...
# 34            Data Analyst als Marketing Manager Automation ...
# 64                                          Senior Data Analyst
# 78                                           Senior Data Expert
# 104                         Senior Software Engineer - Metadata
#
#                    job_location                          job_via  \
# index_number
# 2               Berlin, Germany                     via LinkedIn
# 34            Erlangen, Germany  via Central Illinois Proud Jobs
# 64              Berlin, Germany                        via BeBee
# ...

# %%
german_jobs.head()
# Out:
#                     job_title_short  \
# index_number
# 2                     Data Engineer
# 34                     Data Analyst
# 64              Senior Data Analyst
# 78            Senior Data Scientist
# 104               Software Engineer
#
#                                                       job_title  \
# index_number
# 2             Data Engineer/Scientist/Analyst, Mid or Senior...
# 34            Data Analyst als Marketing Manager Automation ...
# 64                                          Senior Data Analyst
# 78                                           Senior Data Expert
# 104                         Senior Software Engineer - Metadata
#
#                    job_location                          job_via  \
# index_number
# 2               Berlin, Germany                     via LinkedIn
# 34            Erlangen, Germany  via Central Illinois Proud Jobs
# 64              Berlin, Germany                        via BeBee
# ...

# %%
# RESETTING INDEX
german_jobs.reset_index(inplace=False)
german_jobs
# Out:
#               index        job_title_short  \
# index_number
# 2                 0          Data Engineer
# 34                1           Data Analyst
# 64                2    Senior Data Analyst
# 78                3  Senior Data Scientist
# 104               4      Software Engineer
# ...             ...                    ...
# 785728        27689  Senior Data Scientist
# 785729        27690          Data Engineer
# 785732        27691          Data Engineer
# 785735        27692   Senior Data Engineer
# 785737        27693           Data Analyst
#
#                                                       job_title  \
# index_number
# 2             Data Engineer/Scientist/Analyst, Mid or Senior...
# 34            Data Analyst als Marketing Manager Automation ...
# 64                                          Senior Data Analyst
# 78                                           Senior Data Expert
# 104                         Senior Software Engineer - Metadata
# ...

# %%
df.index.name = ('index_number')

# %%
df.head(5)
# Out:
#                    job_title_short  \
# index_number
# 0             Senior Data Engineer
# 1                     Data Analyst
# 2                    Data Engineer
# 3                    Data Engineer
# 4                    Data Engineer
#
#                                                       job_title  \
# index_number
# 0             Senior Clinical Data Engineer / Principal Clin...
# 1                                                  Data Analyst
# 2             Data Engineer/Scientist/Analyst, Mid or Senior...
# 3             LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                        Data Engineer- Sr Jobs
#
#                               job_location             job_via  \
# index_number
# 0                            Watertown, CT     via Work Nearby
# 1             Guadalajara, Jalisco, Mexico    via BeBee México
# 2                          Berlin, Germany        via LinkedIn
# ...

# %%
german_jobs.set_index('index_number', inplace= True)

# %%
german_jobs.reset_index(inplace= True)
german_jobs.head()
# Out:
#    index  index_number        job_title_short  \
# 0      0             2          Data Engineer
# 1      1            34           Data Analyst
# 2      2            64    Senior Data Analyst
# 3      3            78  Senior Data Scientist
# 4      4           104      Software Engineer
#
#                                            job_title       job_location  \
# 0  Data Engineer/Scientist/Analyst, Mid or Senior...    Berlin, Germany
# 1  Data Analyst als Marketing Manager Automation ...  Erlangen, Germany
# 2                                Senior Data Analyst    Berlin, Germany
# 3                                 Senior Data Expert    Berlin, Germany
# 4                Senior Software Engineer - Metadata    Berlin, Germany
#
#                            job_via job_schedule_type  job_work_from_home  \
# 0                     via LinkedIn         Full-time               False
# 1  via Central Illinois Proud Jobs         Full-time               False
# ...

# %%
german_jobs.head(5)
# Out:
#               index        job_title_short  \
# index_number
# 2                 0          Data Engineer
# 34                1           Data Analyst
# 64                2    Senior Data Analyst
# 78                3  Senior Data Scientist
# 104               4      Software Engineer
#
#                                                       job_title  \
# index_number
# 2             Data Engineer/Scientist/Analyst, Mid or Senior...
# 34            Data Analyst als Marketing Manager Automation ...
# 64                                          Senior Data Analyst
# 78                                           Senior Data Expert
# 104                         Senior Software Engineer - Metadata
#
#                    job_location                          job_via  \
# index_number
# 2               Berlin, Germany                     via LinkedIn
# 34            Erlangen, Germany  via Central Illinois Proud Jobs
# 64              Berlin, Germany                        via BeBee
# ...

# %%
df['company_name'].sample(10).sort_index()
# Out:
# index_number
# 118070                   Boston Consulting Group
# 126825    Agensi Pekerjaan ASK Resources Sdn Bhd
# 262489          ADAMA Agricultural Solutions Ltd
# 427592               Greenline Synergy Co., Ltd.
# 505110                      Ringier South Africa
# 507382                     Royal Caribbean Group
# 731768                     People Tech Group Inc
# 747561                          Aditi Consulting
# 748219                            Hydrogen Group
# 758116                           Banco Santander
# Name: company_name, dtype: object

# %%
german_jobs.sample(5)
# Out:
#               index       job_title_short  \
# index_number
# 507637        17745         Data Engineer
# 366466        12356          Data Analyst
# 150237         5421          Data Analyst
# 548778        19323         Data Engineer
# 615838        21744  Senior Data Engineer
#
#                                                       job_title  \
# index_number
# 507637                                    Data Engineer (m/w/d)
# 366466             Data Analyst für die Logistikplanung (m/w/d)
# 150237        (Senior) Business Intelligence / Data Analyst ...
# 548778           German & English speaking Data Centre Engineer
# 615838        Senior Data Engineer - Focus Data Lake Platfor...
#
#                     job_location                         job_via  \
# index_number
# 507637          Cologne, Germany  via SmartRecruiters Job Search
# 366466        Straubing, Germany                    via JobLeads
# 150237            Fürth, Germany                        via XING
# ...
